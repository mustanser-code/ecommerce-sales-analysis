# %%
import pandas as pd

# %%
df = pd.read_csv("sales.csv")

# %%
df.head(4)
# Out:
#    transaction_id  customer_id     customer_name                 email  \
# 0            1001        102.0         Amy Wells  caroladams@gmail.com
# 1            1002        435.0      Joshua Lopez         brownbenjamin
# 2            1003        348.0  Richard Alvarado    rose47@hotmail.com
# 3            1004        270.0    Nichole Nelson     sgibbs@reeves.org
#
#   purchase_date  product_id     category    price  quantity  total_amount  \
# 0    24/01/2024        1023     Clothing  4210.71        -1      -4210.71
# 1    05/09/2023        1029  Electronics  3298.49        -3      -9895.47
# 2    09/07/2024        1078        Books  2387.86         6      14327.16
# 3    28/07/2023        1090     Clothing  3780.65         2       7561.30
#
#   payment_method delivery_status  \
# 0     creditcard         Pending
# 1     Debit Card       Delivered
# 2             CC        Returned
# 3     creditcard         Shipped
#
#                                 customer_address
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1004 non-null   int64
#  1   customer_id       1001 non-null   float64
#  2   customer_name     951 non-null    str
#  3   email             1004 non-null   str
#  4   purchase_date     1004 non-null   str
#  5   product_id        1004 non-null   int64
#  6   category          837 non-null    str
#  7   price             946 non-null    float64
#  8   quantity          1004 non-null   int64
#  9   total_amount      757 non-null    float64
#  10  payment_method    866 non-null    str
#  11  delivery_status   873 non-null    str
#  12  customer_address  950 non-null    str
# dtypes: float64(3), int64(3), str(7)
# memory usage: 102.1 KB

# %%
df.describe()
# Out:
#        transaction_id  customer_id   product_id        price  quantity  \
# count          1004.0       1001.0       1004.0        946.0    1004.0
# mean      1498.614542   251.337662  1050.570717  2512.791765  2.129482
# std        289.787913   141.361692    28.617531  1436.064377  4.302746
# min            1001.0          1.0       1001.0        12.92      -5.0
# 25%           1247.75        134.0       1025.0     1310.025      -1.0
# 50%            1498.5        248.0       1052.0     2531.045       2.0
# 75%           1749.25        373.0       1076.0      3780.65       6.0
# max            2000.0        499.0       1099.0      4998.71       9.0
#
#        total_amount
# count         757.0
# mean    6213.121281
# std    14171.071717
# min        -43614.4
# 25%        -1774.66
# 50%         3760.56
# 75%        13484.96
# max        74608.32
