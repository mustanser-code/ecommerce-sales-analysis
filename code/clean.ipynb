# %%
import pandas as pd
df = pd.read_csv("cleaned_data.csv")

# %%
df = df.drop_duplicates(subset=['transaction_id'], keep='first')

# %%
df = df.drop_duplicates(subset=['transaction_id'],keep='first')

# %%
df["transaction_id"]
# Out:
# 0      1001
# 1      1002
# 2      1003
# 3      1004
# 4      1005
#        ...
# 938    1996
# 939    1997
# 940    1998
# 941    1999
# 942    2000
# Name: transaction_id, Length: 940, dtype: int64

# %%
df['isnull'] = df['quantity']<0
df['isnull']
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 938    False
# 939     True
# 940    False
# 941    False
# 942    False
# Name: isnull, Length: 940, dtype: bool

# %%
df["total_amount"] = df["total_amount"].fillna(df['price']* df['quantity'])

# %%
df['total_amount'] = df['total_amount'].abs()

# %%
df['quantity'] = df['quantity'].abs()

# %%
df.head()
# Out:
#    transaction_id  customer_id     customer_name                 email  \
# 0            1001          102         Amy Wells  caroladams@gmail.com
# 1            1002          435      Joshua Lopez         brownbenjamin
# 2            1003          348  Richard Alvarado    rose47@hotmail.com
# 3            1004          270    Nichole Nelson     sgibbs@reeves.org
# 4            1005          106      Debbie Baker     vvargas@gmail.com
#
#   purchase_date  product_id     category    price  quantity  total_amount  \
# 0    24/01/2024        1023     Clothing  4210.71         1       4210.71
# 1    05/09/2023        1029  Electronics  3298.49         3       9895.47
# 2    09/07/2024        1078        Books  2387.86         6      14327.16
# 3    28/07/2023        1090     Clothing  3780.65         2       7561.30
# 4    10/09/2023        1051         Toys   562.62         5       2813.10
#
#   payment_method delivery_status  \
# 0     creditcard         Pending
# ...

# %%
df['total_amount'] = df['price'] * df['quantity']

# %%
df['customer_name'].isnull().sum()
# Out:
# np.int64(50)

# %%
df['customer_name'] = df['customer_name'].replace("nan","unknown")

# %%
df['customer_address'] = df['customer_address'].replace("nan","unknown")

# %%
df['delivery_status'] = df['delivery_status'].replace("nan","unknown")

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# customer_id         0
# customer_name       0
# email               0
# purchase_date       0
# product_id          0
# category            0
# price               0
# quantity            0
# total_amount        0
# payment_method      0
# delivery_status     0
# customer_address    0
# isnull              0
# dtype: int64

# %%
df.to_csv("clean.csv",index = False)

# %%
df['customer_name']
# Out:
# 0             Amy Wells
# 1          Joshua Lopez
# 2      Richard Alvarado
# 3        Nichole Nelson
# 4          Debbie Baker
#              ...
# 938      Timothy Conley
# 939             unknown
# 940        Julie Acosta
# 941      Nicholas James
# 942       Zachary Lewis
# Name: customer_name, Length: 940, dtype: str

# %%
df['customer_name'] = df['customer_name'].replace("nan", "unknown")
