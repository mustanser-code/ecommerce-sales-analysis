# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("sales.csv")

# %%
## check data type for each of the followning column

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1004 non-null   int64
#  1   customer_id       1001 non-null   float64
#  2   customer_name     951 non-null    str
#  3   email             1004 non-null   str
#  4   purchase_date     1004 non-null   str
#  5   product_id        1004 non-null   int64
#  6   category          837 non-null    str
#  7   price             946 non-null    float64
#  8   quantity          1004 non-null   int64
#  9   total_amount      757 non-null    float64
#  10  payment_method    866 non-null    str
#  11  delivery_status   873 non-null    str
#  12  customer_address  950 non-null    str
# dtypes: float64(3), int64(3), str(7)
# memory usage: 102.1 KB

# %%
# Now convert the columns into relvent data type
df = df.convert_dtypes()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1004 non-null   Int64
#  1   customer_id       1001 non-null   Int64
#  2   customer_name     951 non-null    string
#  3   email             1004 non-null   string
#  4   purchase_date     1004 non-null   string
#  5   product_id        1004 non-null   Int64
#  6   category          837 non-null    string
#  7   price             946 non-null    Float64
#  8   quantity          1004 non-null   Int64
#  9   total_amount      757 non-null    Float64
#  10  payment_method    866 non-null    string
#  11  delivery_status   873 non-null    string
#  12  customer_address  950 non-null    string
# dtypes: Float64(2), Int64(4), string(7)
# memory usage: 108.0 KB

# %%
df = df.dropna(subset=['customer_id','price'],how = "all")
df.isnull().sum()
# Out:
# transaction_id        0
# customer_id           3
# customer_name        53
# email                 0
# purchase_date         0
# product_id            0
# category            167
# price                58
# quantity              0
# total_amount        247
# payment_method      138
# delivery_status     131
# customer_address     54
# dtype: int64

# %%
## how to remove null values in the data frame
df.head()
# Out:
#    transaction_id  customer_id     customer_name                 email  \
# 0            1001          102         Amy Wells  caroladams@gmail.com
# 1            1002          435      Joshua Lopez         brownbenjamin
# 2            1003          348  Richard Alvarado    rose47@hotmail.com
# 3            1004          270    Nichole Nelson     sgibbs@reeves.org
# 4            1005          106      Debbie Baker     vvargas@gmail.com
#
#   purchase_date  product_id     category    price  quantity  total_amount  \
# 0    24/01/2024        1023     Clothing  4210.71        -1      -4210.71
# 1    05/09/2023        1029  Electronics  3298.49        -3      -9895.47
# 2    09/07/2024        1078        Books  2387.86         6      14327.16
# 3    28/07/2023        1090     Clothing  3780.65         2        7561.3
# 4    10/09/2023        1051         Toys   562.62         5          <NA>
#
#   payment_method delivery_status  \
# 0     creditcard         Pending
# ...

# %%
df = df.dropna(subset=["customer_id", "price"])

# %%
df["payment_method"]= df["payment_method"].fillna("unknown")

# %%
df["category"] = df["category"].fillna("unknown")

# %%
df["category"]
# Out:
# 0             Clothing
# 1          Electronics
# 2                Books
# 3             Clothing
# 4                 Toys
#              ...
# 999            unknown
# 1000          Clothing
# 1001    Home & Kitchen
# 1002           unknown
# 1003           unknown
# Name: category, Length: 943, dtype: string

# %%
df["payment_method"]
# Out:
# 0          creditcard
# 1          Debit Card
# 2                  CC
# 3          creditcard
# 4             unknown
#             ...
# 999           unknown
# 1000       creditcard
# 1001           PayPal
# 1002    Bank Transfer
# 1003       Debit Card
# Name: payment_method, Length: 943, dtype: string

# %%
cp = df[["customer_id","price"]]
cp.isnull().sum()
# Out:
# customer_id    0
# price          0
# dtype: int64

# %%
paycat =  df[["category","payment_method"]]
paycat.isnull().sum()
# Out:
# category          0
# payment_method    0
# dtype: int64

# %%
df.head()
# Out:
#    transaction_id  customer_id     customer_name                 email  \
# 0            1001          102         Amy Wells  caroladams@gmail.com
# 1            1002          435      Joshua Lopez         brownbenjamin
# 2            1003          348  Richard Alvarado    rose47@hotmail.com
# 3            1004          270    Nichole Nelson     sgibbs@reeves.org
# 4            1005          106      Debbie Baker     vvargas@gmail.com
#
#   purchase_date  product_id     category    price  quantity  total_amount  \
# 0    24/01/2024        1023     Clothing  4210.71        -1      -4210.71
# 1    05/09/2023        1029  Electronics  3298.49        -3      -9895.47
# 2    09/07/2024        1078        Books  2387.86         6      14327.16
# 3    28/07/2023        1090     Clothing  3780.65         2        7561.3
# 4    10/09/2023        1051         Toys   562.62         5          <NA>
#
#   payment_method delivery_status  \
# 0     creditcard         Pending
# ...

# %%
df["isnull"] = df["quantity"] < 0

# %%
df["quantity"] = df["quantity"].abs()

# %%
df["quantity"]
# Out:
# 0       1
# 1       3
# 2       6
# 3       2
# 4       5
#        ..
# 999     8
# 1000    1
# 1001    4
# 1002    6
# 1003    1
# Name: quantity, Length: 943, dtype: Int64

# %%
df["total_amount"] = df["total_amount"].abs()

# %%
df["total_amount"]
# Out:
# 0        4210.71
# 1        9895.47
# 2       14327.16
# 3         7561.3
# 4           <NA>
#           ...
# 999      25107.6
# 1000     4840.26
# 1001     2751.72
# 1002    11581.08
# 1003     4210.44
# Name: total_amount, Length: 943, dtype: Float64

# %%
df.head(2)
# Out:
#    transaction_id  customer_id customer_name                 email  \
# 0            1001          102     Amy Wells  caroladams@gmail.com
# 1            1002          435  Joshua Lopez         brownbenjamin
#
#   purchase_date  product_id     category    price  quantity  total_amount  \
# 0    24/01/2024        1023     Clothing  4210.71         1       4210.71
# 1    05/09/2023        1029  Electronics  3298.49         3       9895.47
#
#   payment_method delivery_status                          customer_address  \
# 0     creditcard         Pending       5769 Tracy Lane\nPort Amy, AZ 35865
# 1     Debit Card       Delivered  70936 Rangel Falls\nWellshaven, AK 75186
#
#    isnull
# 0    True
# 1    True

# %%
df["total_amount"].isnull().sum()
# Out:
# np.int64(189)

# %%
df["total_amount"] = df["total_amount"].fillna(df["price"] * df["quantity"])

# %%
df["total_amount"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["missing_total"] = df["total_amount"].isna()
df["missing_total"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 999     False
# 1000    False
# 1001    False
# 1002    False
# 1003    False
# Name: missing_total, Length: 943, dtype: bool

# %%
df.to_csv("cleaned.csv",index = False)
